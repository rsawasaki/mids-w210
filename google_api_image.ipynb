# %%
### mulitple locations from csv file ###

import pandas as pd
import re
import requests

# api key and url
api_key = "AIzaSyDzS1CRjfcKoNRDWrx5sg3jnP4ffkT6qNk"
url = "https://maps.googleapis.com/maps/api/staticmap?"

# set the zoom and size
zoom = "21"
size = "600x600"

# read csv file of lat and long
lat_long = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/lat_long_az.csv")

# iterate through each location and produce image
for index, row in lat_long.iterrows():
  center = row['latlong_no_solar']
  request_url = f"{url}center={center}&zoom={zoom}&size={size}&maptype=satellite&format=png&visual_refresh=true&key={api_key}"
  response = requests.get(request_url)
  print(request_url)
  
  # write file 
  with open("/content/drive/MyDrive/Colab Notebooks/600x600/zoom-21/06-01_no_solar_panel_RS_NN/"+center+'+no_solar_panel'+'.png', 'wb') as file:
    file.write(response.content)
# Out:
# https://maps.googleapis.com/maps/api/staticmap?center=33.47798394203118,-112.21099002124242&zoom=21&size=600x600&maptype=satellite&format=png&visual_refresh=true&key=AIzaSyDzS1CRjfcKoNRDWrx5sg3jnP4ffkT6qNk
# https://maps.googleapis.com/maps/api/staticmap?center=33.47679596754135,-112.21373794445806&zoom=21&size=600x600&maptype=satellite&format=png&visual_refresh=true&key=AIzaSyDzS1CRjfcKoNRDWrx5sg3jnP4ffkT6qNk
# https://maps.googleapis.com/maps/api/staticmap?center=33.48437752243204,-112.20232246127075&zoom=21&size=600x600&maptype=satellite&format=png&visual_refresh=true&key=AIzaSyDzS1CRjfcKoNRDWrx5sg3jnP4ffkT6qNk
# https://maps.googleapis.com/maps/api/staticmap?center=33.4907909349244,-112.2058602947108&zoom=21&size=600x600&maptype=satellite&format=png&visual_refresh=true&key=AIzaSyDzS1CRjfcKoNRDWrx5sg3jnP4ffkT6qNk
# ...

# %%
### individual Location ###

import requests
api_key = "AIzaSyDzS1CRjfcKoNRDWrx5sg3jnP4ffkT6qNk"
url = "https://maps.googleapis.com/maps/api/staticmap?"
zoom = "21"
size = "600x600"

# UPDATE lat / long
center = "0.018876713326373775,-78.43339409861825"

request_url = f"{url}center={center}&zoom={zoom}&size={size}&maptype=satellite&format=png&visual_refresh=true&key={api_key}"
print(request_url)
response = requests.get(request_url)

# UPDATE file name
with open('0.011607860348322653,-78.44496365527486'+'+solar_panel'+'.png', 'wb') as file:
   file.write(response.content)
# Out:
# https://maps.googleapis.com/maps/api/staticmap?center=0.018876713326373775,-78.43339409861825&zoom=21&size=600x600&maptype=satellite&format=png&visual_refresh=true&key=AIzaSyDzS1CRjfcKoNRDWrx5sg3jnP4ffkT6qNk
